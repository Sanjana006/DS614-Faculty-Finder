# %%
import pandas as pd

# %%
df=pd.read_csv("daiict_faculty1.csv")

# %%
df.dtypes
# Out:
# Name                  object
# PhD in which field    object
# Mail                  object
# Bio                   object
# Specialization        object
# Research              object
# dtype: object

# %%
df.head()
# Out:
#                       Name                                 PhD in which field  \
# 0           Abhishek Gupta  PhD (Electrical and Computer Engineering), Tor...
# 1            Yash Vasavada  PhD (Electrical Engineering), Virginia Polytec...
# 2             Yash Agrawal    PhD (Electronics & Communication), NIT Hamirpur
# 3         Vinay Palaparthy           PhD (Electrical Engineering), IIT Bombay
# 4  Tathagata Bandyopadhyay  PhD (Statistics), University of Calcutta, Kolkata
#
#                         Mail  \
# 0   abhishek_gupta@dau.ac.in
# 1    yash_vasavada@dau.ac.in
# 2     yash_agrawal@dau.ac.in
# 3  vinay_shrinivas@dau.ac.in
# 4      tathagata_b@dau.ac.in
#
#                                                  Bio  \
# 0  Dr. Abhishek Gupta received his PhD in Electri...
# 1  Yash Vasavada is currently a Professor at DAII...
# 2  Dr. Yash Agrawal received his Ph.D. and M.Tech...
# 3                                                NaN
# ...
